# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as num
from sklearn import linear_model
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Read Dataset File Containing The Housing Information

# %%
KaggleHousingDataset = pd.read_csv("Housing.csv")
KaggleHousingDataset
# Out:
#      area  bedrooms  bathrooms  SalePrice
# 0    7420         4          2   13300000
# 1    8960         4          4   12250000
# 2    9960         3          2   12250000
# 3    7500         4          2   12215000
# 4    7420         4          1   11410000
# ..    ...       ...        ...        ...
# 540  3000         2          1    1820000
# 541  2400         3          1    1767150
# 542  3620         2          1    1750000
# 543  2910         3          1    1750000
# 544  3850         3          1    1750000
#
# [545 rows x 4 columns]

# %% [markdown]
# # Distribute The Dataset into Two Seperate Datasets
#
# Y includes the SalePrice of the Houses, X includes the area, number of bedrooms, and number of houses

# %%
Y = KaggleHousingDataset.SalePrice
Y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: SalePrice, Length: 545, dtype: int64

# %%
X = KaggleHousingDataset.drop(['SalePrice'], axis=1)
X
# Out:
#      area  bedrooms  bathrooms
# 0    7420         4          2
# 1    8960         4          4
# 2    9960         3          2
# 3    7500         4          2
# 4    7420         4          1
# ..    ...       ...        ...
# 540  3000         2          1
# 541  2400         3          1
# 542  3620         2          1
# 543  2910         3          1
# 544  3850         3          1
#
# [545 rows x 3 columns]

# %% [markdown]
# # Split Data into Training and Testing

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
X_train.shape, Y_train.shape
# Out:
# ((436, 3), (436,))

# %%
X_test.shape, Y_test.shape
# Out:
# ((109, 3), (109,))

# %% [markdown]
# # Run the Linear Regression Model

# %%
model = linear_model.LinearRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Predict the Prices using the Test Dataset

# %%
Y_prediction = model.predict(X_test)

# %%
print('Coefficients: ', model.coef_)
print('Intercept: ', model.intercept_)
# Out:
# Coefficients:  [3.67717825e+02 4.10587948e+05 1.38880394e+06]
# Intercept:  -124374.94225091208

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(12, 6))
sns.regplot(x=Y_test, y=Y_prediction)
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual vs Predicted Prices')
plt.show()
